# %% [markdown]
# <a href="https://colab.research.google.com/github/GusBarcenac/Simulacion_notas_de_clase/blob/main/Ejercicio%20en%20clase%2C%20pedido%20de%20producto%202%20junio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Una empresa dedicada a la comercialización de un producto de mucho exito quiere determinar el numero de unidades que debe comprar con el objetivo de satisfacer la demanda de sus clientes los proximos meses. La distribución de las ventas de los ultimos tres años se recoge en la tabla siguiente... (PROBLEMA PLANTEADO EN CLASE)

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
def interferencia():                #Esta función devuelve el valor 1 si hay interferencia o 0 si no la hay.
    interf=0
    x_1 = random.gauss(1.50,0.04)    #La funcion gauss genera un número que sigue una distribucion normal con
    x_2 = random.gauss(1.48,0.03)   # la media y la desvicion estandar especificados.
    if 0.0 < x_2 - x_1:
        interf += 1
    return interf

# %%
lista_bp = []    #Creamos una lista vacía para guardar
pedido=400
puv=1000
pur= 750 #precio unitario de retorno.
bp=0
for i in range(1,700):
    n = (float(round(random.uniform(0, 1),4)))

    #print(n)

    if 0<=n and n<0.22 :
       ventassimu=100

    if 0.22<=n and n<0.47 :
       ventassimu=200

    if 0.47<=n and n<0.58 :
       ventassimu=300


    if 0.58<=n and n<0.83 :
       ventassimu=400


    if 0.83<=n and n<0.94 :
       ventassimu=500

    if 0.94<=n and  n<1:
      ventassimu= 600


    #print(n)
    #print("ventas simuladas",ventassimu,"pedido", pedido)

    if pedido < ventassimu :
       ventasreales=pedido
       beneficio = pedido*1000 - pedido*750


    if pedido>=ventassimu :
       beneficio = (pedido-ventassimu)*250 + ventassimu*1000 - pedido*750


    #print("el beneficio es: ",beneficio)
    bp=(bp+beneficio)
    bpa=bp/i
    #print(i,"beneficio promedio:",bpa)
    lista_bp.append(round(bpa,5))    # Agregamos el beneficio promedio introducido a la lista


plt.plot(lista_bp)   # Dibuja el gráfico
plt.title("Título")   # Establece el título del gráfico
plt.xlabel("abscisa")   # Establece el título del eje x
plt.ylabel("ordenada")   # Establece el título del eje y
#print(lista_bp)
# Out:
# Text(0, 0.5, 'ordenada')

# %%
def ventas_sim():
    ventas=0
    u = random.uniform(0, 1)
    if 0.0 <= u < 0.22:
        ventas = 100
    elif 0.22 <= u < 0.47:
        ventas = 200
    elif 0.47 <= u < 0.58:
        ventas = 300
    elif 0.58 <= u < 0.83:
        ventas = 400
    elif 0.83 <= u <= 94:
        ventas = 500
    elif 0.94 <= u <= 1:
        ventas = 600
    return ventas

# %%
def beneficio(pedido):
    ben = 0
    ventas_reales = 0
    vs = ventas_sim()

    if pedido < vs :
       ventas_reales=pedido
       ben = pedido*1000 - pedido*750

    else:
         ben = (pedido-vs)*250 + vs*1000 - pedido*750

    return ben

# %%
beneficio(400)
# Out:
# 100000

# %%
def simulacion(n):
    L=[]
    benef = 0
    for i in range(n):
        benef += beneficio(400)
        L.append(benef/(i+1))
    return L

# %%
X=simulacion(600)

# %%
plt.plot(X)

# %%
np.mean(X)
# Out:
# 13888.192495789304

# %%
def modelo(n):
    lista=[]
    for i in range(n):
        s = simulacion(500)
        lista.append(np.mean(s))
    return lista

# %%
Y=modelo(100)

# %%
print(np.mean(Y), np.std(Y))
# Out:
# 4219.165472971263 4919.878784514339

# %%
plt.hist(Y)
plt.show()

# %%
def modelo(pedidos):
    valores_x = [100, 200, 300, 400 ,500, 600]
    for x in valores_x:
        print("El valor de x es:", x)

    lista=[]
    for i in range(n):
        s = simulacion(600)
        lista.append(np.mean(s))
    return lista

# %%
def simulaciones(n):
    L=[]
    benef = 0
    valores_x = [100, 200, 300, 400, 500, 600]
    for x in valores_x:
      for i in range(n):
          benef += beneficio(x)
          L.append(benef/(i+1))
    return L

# %%
X=simulaciones(600)

# %%
def beneficios(x):
    beneficio=0
    for x in valores_x:
          beneficio(x)
          print(beneficio(x))
    return (beneficio(x))

# %%
valores_x = [100, 200, 300, 400, 500, 600]
for x in valores_x:
      beneficio(x)
      print(beneficio(x))
# Out:
# 25000
# -25000
# 75000
# -125000
# -25000
# -75000

# %%
valores_x = [100, 200, 300, 400, 500, 600]
lista12=[]
lista13=[]
listar=[0,0,0,0,0,0]
for x in valores_x:
    beneficio(x)

    def simulacion(n):
        L=[]
        benef = 0
        for i in range(n):
            benef += beneficio(x)
            L.append(benef/(i+1))
            return L

    X=simulacion(600)

    np.mean(X)

    def modelo(n):
        lista=[]
        for i in range(n):
            s = simulacion(600)
            lista.append(np.mean(s))
        return lista

    Y=modelo(100)

    print(np.mean(Y), np.std(Y), "con un pedido de :", x)

    lista12.append(np.mean(Y))
# Out:
# 25000.0 0.0 con un pedido de : 100
# 30500.0 32897.56829919196 con un pedido de : 200
# 28500.0 55903.93546075267 con un pedido de : 300
# -2000.0 92173.7489744233 con un pedido de : 400
# -11500.0 113930.90011054947 con un pedido de : 500
# -77250.0 105776.59240115462 con un pedido de : 600

# %%
maximo = max(lista12)
lista13.append(x)
posicion = lista12.index(maximo)

# %% [markdown]
# **POR LO TANTO EL RESULTADO ES:**
# Hacer un pedido de 200 periodicos

# %%
indice_maximo = lista12.index(maximo)
periodicos_pedidos = valores_x[indice_maximo]

print("El beneficio máximo es:", maximo, "Con un pedido de: ", periodicos_pedidos)
# Out:
# El beneficio máximo es: 30500.0 Con un pedido de:  200
